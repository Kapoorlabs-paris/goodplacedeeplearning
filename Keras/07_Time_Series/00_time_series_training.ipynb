# %% [markdown]
# # Predict response to stimuli: GRU for time series

# %% [markdown]
# In a *GRU timeseries* problem, we aim to predict the response of a stimuli, as a time series data. The input is a stimuli vs time and the output is response vs time curve. Depending on how we train the network the response curve could represent average response to the stimuli from different spatial locations or could represet response form a single spatial location.
#
# This notebook builds an GRU based model to predict the response to external stimuli. To do this, we'll provide the model with timeseries of stimuli and use the return sequences to return an output vector that has the same shape as that of the input time series, the output represents response to the stimuli.

# %%
import keras, tensorflow
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from imageio import imread
from IPython import display
from pathlib import Path
import os

# %%
def smooth(x,window_len=11,window='hanning'):
    """smooth the data using a window with requested size.
    
    This method is based on the convolution of a scaled window with the signal.
    The signal is prepared by introducing reflected copies of the signal 
    (with the window size) in both ends so that transient parts are minimized
    in the begining and end part of the output signal.
    
    input:
        x: the input signal 
        window_len: the dimension of the smoothing window; should be an odd integer
        window: the type of window from 'flat', 'hanning', 'hamming', 'bartlett', 'blackman'
            flat window will produce a moving average smoothing.

    output:
        the smoothed signal
        
    example:

    t=linspace(-2,2,0.1)
    x=sin(t)+randn(len(t))*0.1
    y=smooth(x)
    
    see also: 
    
    numpy.hanning, numpy.hamming, numpy.bartlett, numpy.blackman, numpy.convolve
    scipy.signal.lfilter
 
    TODO: the window parameter could be the window itself if an array instead of a string
    NOTE: length(output) != length(input), to correct this: return y[(window_len/2-1):-(window_len/2)] instead of just y.
    """

    if x.ndim != 1:
        raise ValueError("smooth only accepts 1 dimension arrays.")

    if x.size < window_len:
        raise ValueError("Input vector needs to be bigger than window size.")


    if window_len<3:
        return x


    if not window in ['flat', 'hanning', 'hamming', 'bartlett', 'blackman']:
        raise ValueError ("Window is on of 'flat', 'hanning', 'hamming', 'bartlett', 'blackman'")


    s=np.r_[x[window_len-1:0:-1],x,x[-2:-window_len-1:-1]]
    #print(len(s))
    if window == 'flat': #moving average
        w=np.ones(window_len,'d')
    else:
        w=eval('np.'+window+'(window_len)')

    y=np.convolve(w/w.sum(),s,mode='same')
    return y

# %% [markdown]
# The input csv file contains N columns of response as tabular data, we load the data from disk and read it to a numpy array

# %%
display.Image(filename='../images/data_style.jpg')

# %%
data_dir = Path('/home/ubuntu/stimuli_response/')
files = list(data_dir.glob('*.csv'))
stimuli = []
response_roi = []
response = {}
model_name = []
common_name = 'ROI'
sliding_window = 5
start = 128
end = 1536
for count, file in enumerate(files):
    
  stimuli_data = pd.read_csv(file, header=None)
  
  stimuli_data_tuple = stimuli_data.to_numpy()
  stimuli_data_array = np.asarray(stimuli_data_tuple)
  stimuli.append(stimuli_data_array[start:end,0])
  for i in range(1, stimuli_data_array.shape[1]):
    if common_name + str(i) in response.keys():
      response_list = response[common_name + str(i)]
      response_list.append(smooth(stimuli_data_array[:,i], window_len=sliding_window)[
        start:end]) 
    else:  
      response[common_name + str(i)] = [smooth(stimuli_data_array[:,i], window_len=sliding_window)[
        start:end]]
  
stimuli = np.asarray(stimuli)
stimuli = (stimuli - stimuli.mean()) / stimuli.std()
#This is our input data for training
stimuli = np.reshape(stimuli, (count + 1, end - start, 1 ) )
# Now we create a dictionary of the target whose key is the name of the model and value is the training label
for (k,v) in response.items():
    varr = np.asarray(v)
    response[k] = varr
    print('Model Name', k, 'Output data shape', varr.shape)
print('Input data shape', stimuli.shape)    

example_plot = 4
plt.plot(np.arange(stimuli.shape[1]), stimuli[example_plot,:,0])
plt.title('Stimuli'+  str(example_plot))
plt.show()
plt.plot(np.arange(stimuli.shape[1]),response[list(response.keys())[8]][example_plot,:])
plt.title('Response' + str(list(response.keys())[8]))
plt.show()
# Out:
# Model Name ROI1 Output data shape (9, 1408)
# Model Name ROI2 Output data shape (9, 1408)
# Model Name ROI3 Output data shape (9, 1408)
# Model Name ROI4 Output data shape (9, 1408)
# Model Name ROI5 Output data shape (9, 1408)
# Model Name ROI6 Output data shape (9, 1408)
# Model Name ROI7 Output data shape (9, 1408)
# Model Name ROI8 Output data shape (9, 1408)
# Model Name ROI9 Output data shape (9, 1408)
# Model Name ROI10 Output data shape (9, 1408)
# Input data shape (9, 1408, 1)

# %%
input_shape = (stimuli.shape[1],stimuli.shape[2])
units = 4
learning_rate = 0.01
epochs = 150
batch_size = 4
validation_split = 0.1

# %% [markdown]
# The dataset contains 4 colums of the stimuli and the first number represents the number of timepoints present in the data

# %% [markdown]
# GRU Unet

# %%
from keras import layers, models
from keras.layers import GRU, Conv1D, Dense, UpSampling1D, Bidirectional, Conv1D,Dropout,Concatenate, BatchNormalization, MaxPooling1D
inputs = layers.Input(shape = input_shape)
#First Layer
conv1 = GRU(units = units,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' ) (inputs)
conv1 = BatchNormalization()(conv1)
conv1 = GRU(units = units,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' ) (conv1)
conv1 = BatchNormalization()(conv1)
pool1 = MaxPooling1D(pool_size=2) (conv1)

#Second Layer

conv2 = GRU(units = units * 2,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(pool1)
conv2 = BatchNormalization()(conv2)
conv2 = GRU(units = units * 2,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(conv2)
conv2 = BatchNormalization()(conv2)
pool2 = MaxPooling1D(pool_size=2)(conv2)


#Third Layer

conv3 = GRU(units = units * 4,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(pool2)
conv3 = BatchNormalization()(conv3)
conv3 = GRU(units = units * 4,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(conv3)
conv3 = BatchNormalization()(conv3)
pool3 = MaxPooling1D(pool_size=2)(conv3)

#Fourth Layer

conv4 = GRU(units = units * 8,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(pool3)
conv4 = BatchNormalization()(conv4)
conv4 = GRU(units = units * 8,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(conv4)
conv4 = BatchNormalization()(conv4)

#Dropout

drop4 = Dropout(0.5)(conv4)
pool4 = MaxPooling1D(pool_size=2)(drop4)


#Fifth Layer

conv5 = GRU(units = units * 16,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(pool4)
conv5 = BatchNormalization()(conv5)
conv5 = GRU(units = units * 16,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(conv5)
conv5 = BatchNormalization()(conv5)
drop5 = Dropout(0.5)(conv5)

#Upsampling Layers

up6 = GRU(units = units * 8,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(UpSampling1D(size = 2)(drop5))
merge6 = Concatenate(axis=-1)([conv4,up6])
conv6 = GRU(units = units * 8,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(merge6)
conv6 = BatchNormalization()(conv6)
conv6 = GRU(units = units * 8,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(conv6)
conv6 = BatchNormalization()(conv6)

up7 = GRU(units = units * 4,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(UpSampling1D(size = 2)(conv6))
merge7 = Concatenate(axis=-1)([conv3,up7])
conv7 = GRU(units = units * 4,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(merge7)
conv7 = BatchNormalization()(conv7)
conv7 = GRU(units = units * 4,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(conv7)
conv7 = BatchNormalization()(conv7)

up8 = GRU(units = units * 2,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(UpSampling1D(size = 2)(conv7))
merge8 = Concatenate(axis=-1)([conv2,up8])
conv8 = GRU(units = units * 2,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(merge8)
conv8 = BatchNormalization()(conv8)
conv8 = GRU(units = units * 2,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(conv8)
conv8 = BatchNormalization()(conv8)

up9 = GRU(units = units,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(UpSampling1D(size = 2)(conv8))
merge9 = Concatenate(axis=-1)([conv1,up9])
conv9 = GRU(units = units,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(merge9)
conv9 = BatchNormalization()(conv9)
conv9 = GRU(units = units,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(conv9)
conv9 = BatchNormalization()(conv9)
conv9 = GRU(units = units,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(conv9)
conv9 = BatchNormalization()(conv9)
conv10 = GRU(units = 1,  activation = 'relu', return_sequences=True, kernel_initializer = 'he_normal' )(conv9)
outputs = conv10
model = models.Model(inputs, outputs)
opt = keras.optimizers.RMSprop(lr=learning_rate)

model.compile(loss='mse',
              optimizer=opt, metrics = ['mae'])
model.summary()
# Out:
# Model: "model_16"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_18 (InputLayer)          [(None, 1408, 1)]    0           []
#
#  gru_39 (GRU)                   (None, 1408, 4)      84          ['input_18[0][0]']
#
#  batch_normalization_124 (Batch  (None, 1408, 4)     16          ['gru_39[0][0]']
#  Normalization)
#
#  gru_40 (GRU)                   (None, 1408, 4)      120         ['batch_normalization_124[0][0]']
#
#  batch_normalization_125 (Batch  (None, 1408, 4)     16          ['gru_40[0][0]']
#  Normalization)
#
#  max_pooling1d_28 (MaxPooling1D  (None, 704, 4)      0           ['batch_normalization_125[0][0]']
#  )
#
#  gru_41 (GRU)                   (None, 704, 8)       336         ['max_pooling1d_28[0][0]']
#
#  batch_normalization_126 (Batch  (None, 704, 8)      32          ['gru_41[0][0]']
#  Normalization)
#
#  gru_42 (GRU)                   (None, 704, 8)       432         ['batch_normalization_126[0][0]']
#
#  batch_normalization_127 (Batch  (None, 704, 8)      32          ['gru_42[0][0]']
#  Normalization)
#
#  max_pooling1d_29 (MaxPooling1D  (None, 352, 8)      0           ['batch_normalization_127[0][0]']
#  )
#
#  gru_43 (GRU)                   (None, 352, 16)      1248        ['max_pooling1d_29[0][0]']
#
#  batch_normalization_128 (Batch  (None, 352, 16)     64          ['gru_43[0][0]']
#  Normalization)
#
#  gru_44 (GRU)                   (None, 352, 16)      1632        ['batch_normalization_128[0][0]']
#
#  batch_normalization_129 (Batch  (None, 352, 16)     64          ['gru_44[0][0]']
#  Normalization)
#
#  max_pooling1d_30 (MaxPooling1D  (None, 176, 16)     0           ['batch_normalization_129[0][0]']
#  )
#
#  gru_45 (GRU)                   (None, 176, 32)      4800        ['max_pooling1d_30[0][0]']
#
#  batch_normalization_130 (Batch  (None, 176, 32)     128         ['gru_45[0][0]']
#  Normalization)
#
#  gru_46 (GRU)                   (None, 176, 32)      6336        ['batch_normalization_130[0][0]']
#
#  batch_normalization_131 (Batch  (None, 176, 32)     128         ['gru_46[0][0]']
#  Normalization)
#
#  dropout_16 (Dropout)           (None, 176, 32)      0           ['batch_normalization_131[0][0]']
#
#  max_pooling1d_31 (MaxPooling1D  (None, 88, 32)      0           ['dropout_16[0][0]']
#  )
#
#  gru_47 (GRU)                   (None, 88, 64)       18816       ['max_pooling1d_31[0][0]']
#
#  batch_normalization_132 (Batch  (None, 88, 64)      256         ['gru_47[0][0]']
#  Normalization)
#
#  gru_48 (GRU)                   (None, 88, 64)       24960       ['batch_normalization_132[0][0]']
#
#  batch_normalization_133 (Batch  (None, 88, 64)      256         ['gru_48[0][0]']
#  Normalization)
#
#  dropout_17 (Dropout)           (None, 88, 64)       0           ['batch_normalization_133[0][0]']
#
#  up_sampling1d_25 (UpSampling1D  (None, 176, 64)     0           ['dropout_17[0][0]']
#  )
#
#  gru_49 (GRU)                   (None, 176, 32)      9408        ['up_sampling1d_25[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 176, 64)      0           ['batch_normalization_131[0][0]',
#                                                                   'gru_49[0][0]']
#
#  gru_50 (GRU)                   (None, 176, 32)      9408        ['concatenate_25[0][0]']
#
#  batch_normalization_134 (Batch  (None, 176, 32)     128         ['gru_50[0][0]']
#  Normalization)
#
#  gru_51 (GRU)                   (None, 176, 32)      6336        ['batch_normalization_134[0][0]']
#
#  batch_normalization_135 (Batch  (None, 176, 32)     128         ['gru_51[0][0]']
#  Normalization)
#
#  up_sampling1d_26 (UpSampling1D  (None, 352, 32)     0           ['batch_normalization_135[0][0]']
#  )
#
#  gru_52 (GRU)                   (None, 352, 16)      2400        ['up_sampling1d_26[0][0]']
#
#  concatenate_26 (Concatenate)   (None, 352, 32)      0           ['batch_normalization_129[0][0]',
#                                                                   'gru_52[0][0]']
#
#  gru_53 (GRU)                   (None, 352, 16)      2400        ['concatenate_26[0][0]']
#
#  batch_normalization_136 (Batch  (None, 352, 16)     64          ['gru_53[0][0]']
#  Normalization)
#
#  gru_54 (GRU)                   (None, 352, 16)      1632        ['batch_normalization_136[0][0]']
#
#  batch_normalization_137 (Batch  (None, 352, 16)     64          ['gru_54[0][0]']
#  Normalization)
#
#  up_sampling1d_27 (UpSampling1D  (None, 704, 16)     0           ['batch_normalization_137[0][0]']
#  )
#
#  gru_55 (GRU)                   (None, 704, 8)       624         ['up_sampling1d_27[0][0]']
#
#  concatenate_27 (Concatenate)   (None, 704, 16)      0           ['batch_normalization_127[0][0]',
#                                                                   'gru_55[0][0]']
#
#  gru_56 (GRU)                   (None, 704, 8)       624         ['concatenate_27[0][0]']
#
#  batch_normalization_138 (Batch  (None, 704, 8)      32          ['gru_56[0][0]']
#  Normalization)
#
#  gru_57 (GRU)                   (None, 704, 8)       432         ['batch_normalization_138[0][0]']
#
#  batch_normalization_139 (Batch  (None, 704, 8)      32          ['gru_57[0][0]']
#  Normalization)
#
#  up_sampling1d_28 (UpSampling1D  (None, 1408, 8)     0           ['batch_normalization_139[0][0]']
#  )
#
#  gru_58 (GRU)                   (None, 1408, 4)      168         ['up_sampling1d_28[0][0]']
#
#  concatenate_28 (Concatenate)   (None, 1408, 8)      0           ['batch_normalization_125[0][0]',
#                                                                   'gru_58[0][0]']
#
#  gru_59 (GRU)                   (None, 1408, 4)      168         ['concatenate_28[0][0]']
#
#  batch_normalization_140 (Batch  (None, 1408, 4)     16          ['gru_59[0][0]']
#  Normalization)
#
#  gru_60 (GRU)                   (None, 1408, 4)      120         ['batch_normalization_140[0][0]']
#
#  batch_normalization_141 (Batch  (None, 1408, 4)     16          ['gru_60[0][0]']
#  Normalization)
#
#  gru_61 (GRU)                   (None, 1408, 4)      120         ['batch_normalization_141[0][0]']
#
#  batch_normalization_142 (Batch  (None, 1408, 4)     16          ['gru_61[0][0]']
#  Normalization)
#
#  gru_62 (GRU)                   (None, 1408, 1)      21          ['batch_normalization_142[0][0]']
#
# ==================================================================================================
# Total params: 94,113
# Trainable params: 93,369
# Non-trainable params: 744
# __________________________________________________________________________________________________
# /home/ubuntu/anaconda3/envs/naparienv/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/rmsprop.py:140: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %% [markdown]
# Now let us plot the network graph using keras plot_model

# %%
from keras.utils import plot_model

model_inline = plot_model(model, to_file = './model_time_series.png', 
show_shapes = True, show_layer_names=True)

print(model_inline)
model_inline
# Out:
# <IPython.core.display.Image object>

# %%
def plot_history(history):
  plt.figure()
  plt.plot(history.epoch, np.array(history.history['mae']),
           label='Train Loss')
  plt.plot(history.epoch, np.array(history.history['val_mae']),
           label = 'Val loss')
  plt.legend()
  
  plt.show()

# %% [markdown]
# Now let us start the model training by first defining some parameters like epochs, validation_split, keras callbacks etc

# %%
from keras import callbacks
for (k,v) in response.items():
        model_name = k 
        # Keras callbacks
        lrate = callbacks.ReduceLROnPlateau(monitor='loss', factor=0.1, patience=4, verbose=0)
        srate = callbacks.ModelCheckpoint(data_dir.as_posix() +  '/models/' + model_name + '.h5', monitor='loss', verbose=1,
                                          save_best_only=False, save_weights_only=False, mode='auto', period=1)
        history = model.fit(stimuli, v,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose = True,
                    validation_split= validation_split,
                    shuffle=True,
                               callbacks=[lrate, srate])
        plot_history(history)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/150
# 2/2 [==============================] - ETA: 0s - loss: 4009659.5000 - mae: 2002.1069
# Epoch 1: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 70s 8s/step - loss: 4009659.5000 - mae: 2002.1069 - val_loss: 4277663.5000 - val_mae: 2068.0154 - lr: 0.0100
# Epoch 2/150
# 2/2 [==============================] - ETA: 0s - loss: 4008747.7500 - mae: 2001.8782
# Epoch 2: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 4008747.7500 - mae: 2001.8782 - val_loss: 4277319.5000 - val_mae: 2067.9324 - lr: 0.0100
# Epoch 3/150
# 2/2 [==============================] - ETA: 0s - loss: 4007521.5000 - mae: 2001.5728
# Epoch 3: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 4007521.5000 - mae: 2001.5728 - val_loss: 4277459.0000 - val_mae: 2067.9661 - lr: 0.0100
# Epoch 4/150
# 2/2 [==============================] - ETA: 0s - loss: 4006568.0000 - mae: 2001.3337
# Epoch 4: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 4006568.0000 - mae: 2001.3337 - val_loss: 4277511.5000 - val_mae: 2067.9788 - lr: 0.0100
# Epoch 5/150
# 2/2 [==============================] - ETA: 0s - loss: 4005434.0000 - mae: 2001.0503
# Epoch 5: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 4s/step - loss: 4005434.0000 - mae: 2001.0503 - val_loss: 4276344.5000 - val_mae: 2067.6951 - lr: 0.0100
# Epoch 6/150
# 2/2 [==============================] - ETA: 0s - loss: 4003991.0000 - mae: 2000.6895
# Epoch 6: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 4003991.0000 - mae: 2000.6895 - val_loss: 4277737.0000 - val_mae: 2068.0332 - lr: 0.0100
# Epoch 7/150
# 2/2 [==============================] - ETA: 0s - loss: 4002069.0000 - mae: 2000.2115
# Epoch 7: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 4002069.0000 - mae: 2000.2115 - val_loss: 4276706.0000 - val_mae: 2067.7839 - lr: 0.0100
# Epoch 8/150
# 2/2 [==============================] - ETA: 0s - loss: 3999089.5000 - mae: 1999.4646
# Epoch 8: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3999089.5000 - mae: 1999.4646 - val_loss: 4277683.0000 - val_mae: 2068.0198 - lr: 0.0100
# Epoch 9/150
# 2/2 [==============================] - ETA: 0s - loss: 3995349.5000 - mae: 1998.5355
# Epoch 9: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3995349.5000 - mae: 1998.5355 - val_loss: 4277558.0000 - val_mae: 2067.9897 - lr: 0.0100
# Epoch 10/150
# 2/2 [==============================] - ETA: 0s - loss: 3993594.0000 - mae: 1998.0966
# Epoch 10: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3993594.0000 - mae: 1998.0966 - val_loss: 4277668.0000 - val_mae: 2068.0164 - lr: 0.0100
# Epoch 11/150
# 2/2 [==============================] - ETA: 0s - loss: 3991397.0000 - mae: 1997.5427
# Epoch 11: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 3991397.0000 - mae: 1997.5427 - val_loss: 4277681.5000 - val_mae: 2068.0195 - lr: 0.0100
# Epoch 12/150
# 2/2 [==============================] - ETA: 0s - loss: 3985314.0000 - mae: 1996.0273
# Epoch 12: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3985314.0000 - mae: 1996.0273 - val_loss: 4278008.0000 - val_mae: 2068.0986 - lr: 0.0100
# Epoch 13/150
# 2/2 [==============================] - ETA: 0s - loss: 3984283.2500 - mae: 1995.7725
# Epoch 13: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 3984283.2500 - mae: 1995.7725 - val_loss: 4278007.5000 - val_mae: 2068.0986 - lr: 0.0100
# Epoch 14/150
# 2/2 [==============================] - ETA: 0s - loss: 3977467.0000 - mae: 1994.0564
# Epoch 14: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3977467.0000 - mae: 1994.0564 - val_loss: 4278008.5000 - val_mae: 2068.0991 - lr: 0.0100
# Epoch 15/150
# 2/2 [==============================] - ETA: 0s - loss: 3971140.5000 - mae: 1992.4739
# Epoch 15: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3971140.5000 - mae: 1992.4739 - val_loss: 4278007.5000 - val_mae: 2068.0986 - lr: 0.0100
# Epoch 16/150
# 2/2 [==============================] - ETA: 0s - loss: 3969159.0000 - mae: 1991.9744
# Epoch 16: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 4s/step - loss: 3969159.0000 - mae: 1991.9744 - val_loss: 4278006.5000 - val_mae: 2068.0984 - lr: 0.0100
# Epoch 17/150
# 2/2 [==============================] - ETA: 0s - loss: 3957016.7500 - mae: 1988.9500
# Epoch 17: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 3957016.7500 - mae: 1988.9500 - val_loss: 4278006.0000 - val_mae: 2068.0984 - lr: 0.0100
# Epoch 18/150
# 2/2 [==============================] - ETA: 0s - loss: 3951800.0000 - mae: 1987.6428
# Epoch 18: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3951800.0000 - mae: 1987.6428 - val_loss: 4278004.5000 - val_mae: 2068.0979 - lr: 0.0100
# Epoch 19/150
# 2/2 [==============================] - ETA: 0s - loss: 3957164.0000 - mae: 1988.9902
# Epoch 19: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 4s/step - loss: 3957164.0000 - mae: 1988.9902 - val_loss: 4276819.0000 - val_mae: 2067.8103 - lr: 0.0100
# Epoch 20/150
# 2/2 [==============================] - ETA: 0s - loss: 3947168.5000 - mae: 1986.4170
# Epoch 20: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 3947168.5000 - mae: 1986.4170 - val_loss: 4277769.0000 - val_mae: 2068.0408 - lr: 0.0100
# Epoch 21/150
# 2/2 [==============================] - ETA: 0s - loss: 3930798.0000 - mae: 1982.3588
# Epoch 21: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3930798.0000 - mae: 1982.3588 - val_loss: 4277964.0000 - val_mae: 2068.0881 - lr: 0.0100
# Epoch 22/150
# 2/2 [==============================] - ETA: 0s - loss: 3931213.5000 - mae: 1982.4407
# Epoch 22: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 3931213.5000 - mae: 1982.4407 - val_loss: 4274563.0000 - val_mae: 2067.2620 - lr: 0.0100
# Epoch 23/150
# 2/2 [==============================] - ETA: 0s - loss: 3918743.5000 - mae: 1979.2971
# Epoch 23: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 3918743.5000 - mae: 1979.2971 - val_loss: 4277298.0000 - val_mae: 2067.9268 - lr: 0.0100
# Epoch 24/150
# 2/2 [==============================] - ETA: 0s - loss: 3915373.0000 - mae: 1978.3357
# Epoch 24: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 4s/step - loss: 3915373.0000 - mae: 1978.3357 - val_loss: 4277978.0000 - val_mae: 2068.0916 - lr: 0.0100
# Epoch 25/150
# 2/2 [==============================] - ETA: 0s - loss: 3893208.0000 - mae: 1972.8539
# Epoch 25: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3893208.0000 - mae: 1972.8539 - val_loss: 4277967.0000 - val_mae: 2068.0889 - lr: 0.0100
# Epoch 26/150
# 2/2 [==============================] - ETA: 0s - loss: 3856215.5000 - mae: 1963.3365
# Epoch 26: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3856215.5000 - mae: 1963.3365 - val_loss: 4277991.0000 - val_mae: 2068.0947 - lr: 0.0100
# Epoch 27/150
# 2/2 [==============================] - ETA: 0s - loss: 3845460.5000 - mae: 1960.3960
# Epoch 27: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3845460.5000 - mae: 1960.3960 - val_loss: 4277974.0000 - val_mae: 2068.0906 - lr: 0.0100
# Epoch 28/150
# 2/2 [==============================] - ETA: 0s - loss: 3724073.7500 - mae: 1929.0708
# Epoch 28: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3724073.7500 - mae: 1929.0708 - val_loss: 4277972.5000 - val_mae: 2068.0901 - lr: 0.0100
# Epoch 29/150
# 2/2 [==============================] - ETA: 0s - loss: 3647222.5000 - mae: 1908.3969
# Epoch 29: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3647222.5000 - mae: 1908.3969 - val_loss: 4277958.0000 - val_mae: 2068.0867 - lr: 0.0100
# Epoch 30/150
# 2/2 [==============================] - ETA: 0s - loss: 3712360.0000 - mae: 1926.4092
# Epoch 30: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3712360.0000 - mae: 1926.4092 - val_loss: 4277844.5000 - val_mae: 2068.0593 - lr: 0.0100
# Epoch 31/150
# 2/2 [==============================] - ETA: 0s - loss: 3474454.2500 - mae: 1861.7628
# Epoch 31: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 4s/step - loss: 3474454.2500 - mae: 1861.7628 - val_loss: 4277431.0000 - val_mae: 2067.9595 - lr: 0.0100
# Epoch 32/150
# 2/2 [==============================] - ETA: 0s - loss: 3512726.0000 - mae: 1872.1611
# Epoch 32: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3512726.0000 - mae: 1872.1611 - val_loss: 4276909.0000 - val_mae: 2067.8337 - lr: 0.0100
# Epoch 33/150
# 2/2 [==============================] - ETA: 0s - loss: 3654885.5000 - mae: 1911.2666
# Epoch 33: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 4s/step - loss: 3654885.5000 - mae: 1911.2666 - val_loss: 4276721.0000 - val_mae: 2067.7883 - lr: 0.0100
# Epoch 34/150
# 2/2 [==============================] - ETA: 0s - loss: 3419171.2500 - mae: 1846.8574
# Epoch 34: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 3419171.2500 - mae: 1846.8574 - val_loss: 4275850.5000 - val_mae: 2067.5781 - lr: 0.0100
# Epoch 35/150
# 2/2 [==============================] - ETA: 0s - loss: 3483288.5000 - mae: 1864.4541
# Epoch 35: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3483288.5000 - mae: 1864.4541 - val_loss: 4274860.5000 - val_mae: 2067.3389 - lr: 0.0100
# Epoch 36/150
# 2/2 [==============================] - ETA: 0s - loss: 3362618.7500 - mae: 1831.1311
# Epoch 36: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 3362618.7500 - mae: 1831.1311 - val_loss: 4268927.5000 - val_mae: 2065.9033 - lr: 0.0100
# Epoch 37/150
# 2/2 [==============================] - ETA: 0s - loss: 3425395.5000 - mae: 1850.3857
# Epoch 37: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3425395.5000 - mae: 1850.3857 - val_loss: 4258520.5000 - val_mae: 2063.3828 - lr: 0.0100
# Epoch 38/150
# 2/2 [==============================] - ETA: 0s - loss: 3318288.7500 - mae: 1821.1918
# Epoch 38: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 4s/step - loss: 3318288.7500 - mae: 1821.1918 - val_loss: 4247817.0000 - val_mae: 2060.7871 - lr: 0.0100
# Epoch 39/150
# 2/2 [==============================] - ETA: 0s - loss: 3231087.0000 - mae: 1796.9817
# Epoch 39: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3231087.0000 - mae: 1796.9817 - val_loss: 4238910.5000 - val_mae: 2058.6248 - lr: 0.0100
# Epoch 40/150
# 2/2 [==============================] - ETA: 0s - loss: 3076388.7500 - mae: 1751.2865
# Epoch 40: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3076388.7500 - mae: 1751.2865 - val_loss: 4231504.0000 - val_mae: 2056.8250 - lr: 0.0100
# Epoch 41/150
# 2/2 [==============================] - ETA: 0s - loss: 3040774.5000 - mae: 1743.2372
# Epoch 41: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3040774.5000 - mae: 1743.2372 - val_loss: 4225059.0000 - val_mae: 2055.2576 - lr: 0.0100
# Epoch 42/150
# 2/2 [==============================] - ETA: 0s - loss: 3030145.2500 - mae: 1740.1770
# Epoch 42: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 3030145.2500 - mae: 1740.1770 - val_loss: 4216843.5000 - val_mae: 2053.2578 - lr: 0.0100
# Epoch 43/150
# 2/2 [==============================] - ETA: 0s - loss: 2977251.5000 - mae: 1724.8932
# Epoch 43: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 2977251.5000 - mae: 1724.8932 - val_loss: 4208228.5000 - val_mae: 2051.1587 - lr: 0.0100
# Epoch 44/150
# 2/2 [==============================] - ETA: 0s - loss: 2943088.5000 - mae: 1715.2118
# Epoch 44: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 2943088.5000 - mae: 1715.2118 - val_loss: 4199934.5000 - val_mae: 2049.1362 - lr: 0.0100
# Epoch 45/150
# 2/2 [==============================] - ETA: 0s - loss: 2906588.5000 - mae: 1704.3556
# Epoch 45: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 2906588.5000 - mae: 1704.3556 - val_loss: 4192326.5000 - val_mae: 2047.2789 - lr: 0.0100
# Epoch 46/150
# 2/2 [==============================] - ETA: 0s - loss: 2827937.5000 - mae: 1680.9331
# Epoch 46: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 2827937.5000 - mae: 1680.9331 - val_loss: 4183605.5000 - val_mae: 2045.1477 - lr: 0.0100
# Epoch 47/150
# 2/2 [==============================] - ETA: 0s - loss: 2904879.0000 - mae: 1701.5955
# Epoch 47: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 4s/step - loss: 2904879.0000 - mae: 1701.5955 - val_loss: 4176571.0000 - val_mae: 2043.4274 - lr: 0.0100
# Epoch 48/150
# 2/2 [==============================] - ETA: 0s - loss: 2771322.0000 - mae: 1664.2415
# Epoch 48: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 2771322.0000 - mae: 1664.2415 - val_loss: 4166613.0000 - val_mae: 2040.9894 - lr: 0.0100
# Epoch 49/150
# 2/2 [==============================] - ETA: 0s - loss: 2665223.5000 - mae: 1632.0957
# Epoch 49: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 2665223.5000 - mae: 1632.0957 - val_loss: 4159008.7500 - val_mae: 2039.1254 - lr: 0.0100
# Epoch 50/150
# 2/2 [==============================] - ETA: 0s - loss: 2648819.0000 - mae: 1626.7915
# Epoch 50: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 2648819.0000 - mae: 1626.7915 - val_loss: 4150370.2500 - val_mae: 2037.0063 - lr: 0.0100
# Epoch 51/150
# 2/2 [==============================] - ETA: 0s - loss: 2541747.5000 - mae: 1593.8723
# Epoch 51: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 2541747.5000 - mae: 1593.8723 - val_loss: 4141005.5000 - val_mae: 2034.7063 - lr: 0.0100
# Epoch 52/150
# 2/2 [==============================] - ETA: 0s - loss: 2541022.5000 - mae: 1593.6904
# Epoch 52: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 2541022.5000 - mae: 1593.6904 - val_loss: 4131795.2500 - val_mae: 2032.4418 - lr: 0.0100
# Epoch 53/150
# 2/2 [==============================] - ETA: 0s - loss: 2465014.0000 - mae: 1569.6147
# Epoch 53: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 4s/step - loss: 2465014.0000 - mae: 1569.6147 - val_loss: 4122464.2500 - val_mae: 2030.1449 - lr: 0.0100
# Epoch 54/150
# 2/2 [==============================] - ETA: 0s - loss: 2488188.0000 - mae: 1577.0220
# Epoch 54: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 2488188.0000 - mae: 1577.0220 - val_loss: 4110083.0000 - val_mae: 2027.0934 - lr: 0.0100
# Epoch 55/150
# 2/2 [==============================] - ETA: 0s - loss: 2404721.7500 - mae: 1550.3403
# Epoch 55: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 2404721.7500 - mae: 1550.3403 - val_loss: 4099099.0000 - val_mae: 2024.3821 - lr: 0.0100
# Epoch 56/150
# 2/2 [==============================] - ETA: 0s - loss: 2331541.0000 - mae: 1526.5546
# Epoch 56: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 2331541.0000 - mae: 1526.5546 - val_loss: 4088199.2500 - val_mae: 2021.6884 - lr: 0.0100
# Epoch 57/150
# 2/2 [==============================] - ETA: 0s - loss: 2304067.0000 - mae: 1517.5037
# Epoch 57: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 2304067.0000 - mae: 1517.5037 - val_loss: 4076670.5000 - val_mae: 2018.8352 - lr: 0.0100
# Epoch 58/150
# 2/2 [==============================] - ETA: 0s - loss: 2311984.5000 - mae: 1520.0985
# Epoch 58: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 2311984.5000 - mae: 1520.0985 - val_loss: 4067117.0000 - val_mae: 2016.4677 - lr: 0.0100
# Epoch 59/150
# 2/2 [==============================] - ETA: 0s - loss: 2211773.7500 - mae: 1486.7424
# Epoch 59: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 2211773.7500 - mae: 1486.7424 - val_loss: 4054572.2500 - val_mae: 2013.3546 - lr: 0.0100
# Epoch 60/150
# 2/2 [==============================] - ETA: 0s - loss: 2185403.5000 - mae: 1477.8348
# Epoch 60: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 2185403.5000 - mae: 1477.8348 - val_loss: 4040984.7500 - val_mae: 2009.9773 - lr: 0.0100
# Epoch 61/150
# 2/2 [==============================] - ETA: 0s - loss: 2272679.7500 - mae: 1507.0990
# Epoch 61: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 4s/step - loss: 2272679.7500 - mae: 1507.0990 - val_loss: 4025248.0000 - val_mae: 2006.0590 - lr: 0.0100
# Epoch 62/150
# 2/2 [==============================] - ETA: 0s - loss: 2152772.5000 - mae: 1466.8020
# Epoch 62: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 4s/step - loss: 2152772.5000 - mae: 1466.8020 - val_loss: 4012535.7500 - val_mae: 2002.8882 - lr: 0.0100
# Epoch 63/150
# 2/2 [==============================] - ETA: 0s - loss: 2235790.0000 - mae: 1494.7977
# Epoch 63: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 2235790.0000 - mae: 1494.7977 - val_loss: 4001639.0000 - val_mae: 2000.1659 - lr: 0.0100
# Epoch 64/150
# 2/2 [==============================] - ETA: 0s - loss: 2084578.2500 - mae: 1443.3309
# Epoch 64: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 2084578.2500 - mae: 1443.3309 - val_loss: 3987494.2500 - val_mae: 1996.6268 - lr: 0.0100
# Epoch 65/150
# 2/2 [==============================] - ETA: 0s - loss: 2071733.0000 - mae: 1438.8986
# Epoch 65: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 2071733.0000 - mae: 1438.8986 - val_loss: 3974158.5000 - val_mae: 1993.2844 - lr: 0.0100
# Epoch 66/150
# 2/2 [==============================] - ETA: 0s - loss: 2003644.2500 - mae: 1415.0486
# Epoch 66: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 2003644.2500 - mae: 1415.0486 - val_loss: 3957978.2500 - val_mae: 1989.2218 - lr: 0.0100
# Epoch 67/150
# 2/2 [==============================] - ETA: 0s - loss: 1974095.5000 - mae: 1404.5398
# Epoch 67: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 1974095.5000 - mae: 1404.5398 - val_loss: 3942964.7500 - val_mae: 1985.4442 - lr: 0.0100
# Epoch 68/150
# 2/2 [==============================] - ETA: 0s - loss: 1941285.1250 - mae: 1392.7644
# Epoch 68: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 1941285.1250 - mae: 1392.7644 - val_loss: 3927915.7500 - val_mae: 1981.6508 - lr: 0.0100
# Epoch 69/150
# 2/2 [==============================] - ETA: 0s - loss: 1928958.7500 - mae: 1388.4099
# Epoch 69: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 4s/step - loss: 1928958.7500 - mae: 1388.4099 - val_loss: 3912453.5000 - val_mae: 1977.7454 - lr: 0.0100
# Epoch 70/150
# 2/2 [==============================] - ETA: 0s - loss: 1906976.5000 - mae: 1380.5115
# Epoch 70: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 1906976.5000 - mae: 1380.5115 - val_loss: 3892592.7500 - val_mae: 1972.7184 - lr: 0.0100
# Epoch 71/150
# 2/2 [==============================] - ETA: 0s - loss: 1820643.0000 - mae: 1348.9049
# Epoch 71: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 4s/step - loss: 1820643.0000 - mae: 1348.9049 - val_loss: 3874369.0000 - val_mae: 1968.0938 - lr: 0.0100
# Epoch 72/150
# 2/2 [==============================] - ETA: 0s - loss: 1831437.2500 - mae: 1352.8550
# Epoch 72: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 1831437.2500 - mae: 1352.8550 - val_loss: 3857414.5000 - val_mae: 1963.7816 - lr: 0.0100
# Epoch 73/150
# 2/2 [==============================] - ETA: 0s - loss: 1772697.2500 - mae: 1330.9255
# Epoch 73: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 4s/step - loss: 1772697.2500 - mae: 1330.9255 - val_loss: 3839407.2500 - val_mae: 1959.1914 - lr: 0.0100
# Epoch 74/150
# 2/2 [==============================] - ETA: 0s - loss: 1741548.7500 - mae: 1319.1812
# Epoch 74: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 1741548.7500 - mae: 1319.1812 - val_loss: 3820328.7500 - val_mae: 1954.3164 - lr: 0.0100
# Epoch 75/150
# 2/2 [==============================] - ETA: 0s - loss: 1698839.2500 - mae: 1302.9062
# Epoch 75: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 4s/step - loss: 1698839.2500 - mae: 1302.9062 - val_loss: 3798239.2500 - val_mae: 1948.6570 - lr: 0.0100
# Epoch 76/150
# 2/2 [==============================] - ETA: 0s - loss: 1702246.1250 - mae: 1304.1981
# Epoch 76: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 1702246.1250 - mae: 1304.1981 - val_loss: 3778688.2500 - val_mae: 1943.6339 - lr: 0.0100
# Epoch 77/150
# 2/2 [==============================] - ETA: 0s - loss: 1676825.2500 - mae: 1294.3961
# Epoch 77: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 1676825.2500 - mae: 1294.3961 - val_loss: 3759750.5000 - val_mae: 1938.7560 - lr: 0.0100
# Epoch 78/150
# 2/2 [==============================] - ETA: 0s - loss: 1602876.2500 - mae: 1265.5295
# Epoch 78: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 1602876.2500 - mae: 1265.5295 - val_loss: 3735972.0000 - val_mae: 1932.6138 - lr: 0.0100
# Epoch 79/150
# 2/2 [==============================] - ETA: 0s - loss: 1628432.5000 - mae: 1275.4915
# Epoch 79: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 4s/step - loss: 1628432.5000 - mae: 1275.4915 - val_loss: 3711828.2500 - val_mae: 1926.3574 - lr: 0.0100
# Epoch 80/150
# 2/2 [==============================] - ETA: 0s - loss: 1587608.7500 - mae: 1259.4241
# Epoch 80: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 1587608.7500 - mae: 1259.4241 - val_loss: 3689683.7500 - val_mae: 1920.6008 - lr: 0.0100
# Epoch 81/150
# 2/2 [==============================] - ETA: 0s - loss: 1535463.7500 - mae: 1238.6519
# Epoch 81: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 1535463.7500 - mae: 1238.6519 - val_loss: 3673169.5000 - val_mae: 1916.2969 - lr: 0.0100
# Epoch 82/150
# 2/2 [==============================] - ETA: 0s - loss: 1489587.2500 - mae: 1219.9150
# Epoch 82: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 1489587.2500 - mae: 1219.9150 - val_loss: 3646852.0000 - val_mae: 1909.4176 - lr: 0.0100
# Epoch 83/150
# 2/2 [==============================] - ETA: 0s - loss: 1447210.3750 - mae: 1202.4731
# Epoch 83: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 1447210.3750 - mae: 1202.4731 - val_loss: 3621268.2500 - val_mae: 1902.7067 - lr: 0.0100
# Epoch 84/150
# 2/2 [==============================] - ETA: 0s - loss: 1454708.0000 - mae: 1205.5740
# Epoch 84: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 1454708.0000 - mae: 1205.5740 - val_loss: 3599279.7500 - val_mae: 1896.9198 - lr: 0.0100
# Epoch 85/150
# 2/2 [==============================] - ETA: 0s - loss: 1398875.2500 - mae: 1182.1848
# Epoch 85: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 1398875.2500 - mae: 1182.1848 - val_loss: 3571362.2500 - val_mae: 1889.5465 - lr: 0.0100
# Epoch 86/150
# 2/2 [==============================] - ETA: 0s - loss: 1392855.5000 - mae: 1179.6245
# Epoch 86: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 4s/step - loss: 1392855.5000 - mae: 1179.6245 - val_loss: 3547963.2500 - val_mae: 1883.3448 - lr: 0.0100
# Epoch 87/150
# 2/2 [==============================] - ETA: 0s - loss: 1344268.8750 - mae: 1158.8448
# Epoch 87: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 1344268.8750 - mae: 1158.8448 - val_loss: 3522192.2500 - val_mae: 1876.4904 - lr: 0.0100
# Epoch 88/150
# 2/2 [==============================] - ETA: 0s - loss: 1307570.2500 - mae: 1142.9618
# Epoch 88: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 1307570.2500 - mae: 1142.9618 - val_loss: 3491755.7500 - val_mae: 1868.3629 - lr: 0.0100
# Epoch 89/150
# 2/2 [==============================] - ETA: 0s - loss: 1291087.1250 - mae: 1135.6931
# Epoch 89: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 1291087.1250 - mae: 1135.6931 - val_loss: 3469207.2500 - val_mae: 1862.3188 - lr: 0.0100
# Epoch 90/150
# 2/2 [==============================] - ETA: 0s - loss: 1245869.2500 - mae: 1115.4832
# Epoch 90: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 1245869.2500 - mae: 1115.4832 - val_loss: 3441632.0000 - val_mae: 1854.9005 - lr: 0.0100
# Epoch 91/150
# 2/2 [==============================] - ETA: 0s - loss: 1214914.6250 - mae: 1101.6635
# Epoch 91: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 1214914.6250 - mae: 1101.6635 - val_loss: 3407161.0000 - val_mae: 1845.5856 - lr: 0.0100
# Epoch 92/150
# 2/2 [==============================] - ETA: 0s - loss: 1181247.5000 - mae: 1086.2920
# Epoch 92: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 1181247.5000 - mae: 1086.2920 - val_loss: 3378379.0000 - val_mae: 1837.7714 - lr: 0.0100
# Epoch 93/150
# 2/2 [==============================] - ETA: 0s - loss: 1147483.7500 - mae: 1070.6432
# Epoch 93: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 9s 5s/step - loss: 1147483.7500 - mae: 1070.6432 - val_loss: 3345428.2500 - val_mae: 1828.7844 - lr: 0.0100
# Epoch 94/150
# 2/2 [==============================] - ETA: 0s - loss: 1132770.0000 - mae: 1063.7512
# Epoch 94: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 1132770.0000 - mae: 1063.7512 - val_loss: 3310250.2500 - val_mae: 1819.1411 - lr: 0.0100
# Epoch 95/150
# 2/2 [==============================] - ETA: 0s - loss: 1094003.5000 - mae: 1045.3309
# Epoch 95: saving model to /home/ubuntu/stimuli_response/models/ROI1.h5
# 2/2 [==============================] - 8s 5s/step - loss: 1094003.5000 - mae: 1045.3309 - val_loss: 3278516.0000 - val_mae: 1810.3977 - lr: 0.0100
# Epoch 96/150
# 2/2 [==============================] - ETA: 0s - loss: 1073704.5000 - mae: 1035.5288

# %% [markdown]
# UNET usual but in 1D

# %%
from keras import layers, models
from keras.layers import ConvGRU1D, GRU, Conv1D, Dense, UpSampling1D, Bidirectional, Conv1D,Dropout,Concatenate, BatchNormalization, MaxPooling1D
inputs = layers.Input(shape = input_shape)
#First Layer
conv1 = Conv1D(units, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal' ) (inputs)
conv1 = BatchNormalization()(conv1)
conv1 = Conv1D(units, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal' ) (conv1)
conv1 = BatchNormalization()(conv1)
pool1 = MaxPooling1D(pool_size=2) (conv1)

#Second Layer

conv2 = Conv1D(units * 2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
conv2 = BatchNormalization()(conv2)
conv2 = Conv1D(units * 2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
conv2 = BatchNormalization()(conv2)
pool2 = MaxPooling1D(pool_size=2)(conv2)


#Third Layer

conv3 = Conv1D(units * 4, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
conv3 = BatchNormalization()(conv3)
conv3 = Conv1D(units * 4, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
conv3 = BatchNormalization()(conv3)
pool3 = MaxPooling1D(pool_size=2)(conv3)

#Fourth Layer

conv4 = Conv1D(units * 8, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
conv4 = BatchNormalization()(conv4)
conv4 = Conv1D(units * 8, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
conv4 = BatchNormalization()(conv4)

#Dropout

drop4 = Dropout(0.5)(conv4)
pool4 = MaxPooling1D(pool_size=2)(drop4)


#Fifth Layer

conv5 = Conv1D(units * 16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
conv5 = BatchNormalization()(conv5)
conv5 = Conv1D(units * 16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
conv5 = BatchNormalization()(conv5)
drop5 = Dropout(0.5)(conv5)

#Upsampling Layers

up6 = Conv1D(units * 8, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling1D(size = 2)(drop5))
merge6 = Concatenate(axis=-1)([conv4,up6])
conv6 = Conv1D(units * 8, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
conv6 = BatchNormalization()(conv6)
conv6 = Conv1D(units * 8, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
conv6 = BatchNormalization()(conv6)

up7 = Conv1D(units * 4 , 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling1D(size = 2)(conv6))
merge7 = Concatenate(axis=-1)([conv3,up7])
conv7 = Conv1D(units * 4 , 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
conv7 = BatchNormalization()(conv7)
conv7 = Conv1D(units * 4, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
conv7 = BatchNormalization()(conv7)

up8 = Conv1D(units  * 2, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling1D(size = 2)(conv7))
merge8 = Concatenate(axis=-1)([conv2,up8])
conv8 = Conv1D(units  * 2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
conv8 = BatchNormalization()(conv8)
conv8 = Conv1D(units  * 2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
conv8 = BatchNormalization()(conv8)

up9 = Conv1D(units, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling1D(size = 2)(conv8))
merge9 = Concatenate(axis=-1)([conv1,up9])
conv9 = Conv1D(units, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
conv9 = BatchNormalization()(conv9)
conv9 = Conv1D(units, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
conv9 = BatchNormalization()(conv9)
conv9 = Conv1D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
conv9 = BatchNormalization()(conv9)
conv10 = Conv1D(1, 1, activation = 'linear')(conv9)
outputs = conv10
model = models.Model(inputs, outputs)
opt = keras.optimizers.RMSprop(lr=learning_rate)

model.compile(loss='mse',
              optimizer=opt, metrics = ['mae'])
model.summary()

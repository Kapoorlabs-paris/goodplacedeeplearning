# %% [markdown]
# # Predict response to stimuli: lstm for time series

# %% [markdown]
# In a *lstm timeseries* problem, we aim to predict the response of a stimuli, as a time series data. The input is a stimuli vs time and the output is response vs time curve. Depending on how we train the network the response curve could represent average response to the stimuli from different spatial locations or could represet response form a single spatial location.
#
# This notebook builds an LSTM based model to predict the response to external stimuli. To do this, we'll provide the model with timeseries of stimuli and use the return sequences to return an output vector that has the same shape as that of the input time series, the output represents response to the stimuli.

# %%
import keras, tensorflow
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from imageio import imread
from IPython import display

# %% [markdown]
# The input csv file contains N columns of response as tabular data, we load the data from disk and read it to a numpy array

# %%
display.Image(filename='../images/data_style.jpg')

# %%
stimuli_data = pd.read_csv("../stimuli_response_data/stimuli.csv")
stimuli_data_tuple = stimuli_data.to_numpy()
stimuli_data_array = np.asarray(stimuli_data_tuple)
type(stimuli_data_array)

stimuli_data_array = np.reshape(stimuli_data_array, (stimuli_data_array.shape[1], stimuli_data_array.shape[0], 1))

print("input data shape",stimuli_data_array.shape)
# Out:
# input data shape (4, 999, 1)

# %%
input_shape = (stimuli_data_array.shape[1],stimuli_data_array.shape[2])
lstm_units = 128
learning_rate = 0.01
epochs = 150
batch_size = 4
validation_split = 0.1

# %% [markdown]
# Now we create the ground truth data which are responses from specific locations that correspond to the stimuli

# %%
response_data = pd.read_csv("../stimuli_response_data/stimuli.csv")
response_data_tuple = response_data.to_numpy()
response_data_array = np.asarray(response_data_tuple)
type(response_data_array)
response_data_array = np.reshape(response_data_array, (response_data_array.shape[1], response_data_array.shape[0]))

# %% [markdown]
# The dataset contains 4 colums of the stimuli and the first number represents the number of timepoints present in the data

# %%
from keras import layers, models
from keras.layers import ConvLSTM1D, LSTM, Conv1D, Dense, Bidirectional
img_input = layers.Input(shape = input_shape)
x = (LSTM(lstm_units, return_sequences=True))(img_input)

x = Dense(lstm_units, activation= 'linear')(x)
x = Dense(1, activation= 'linear')(x)
outputs = x
model = models.Model(img_input, outputs)
opt = keras.optimizers.RMSprop(lr=learning_rate)

model.compile(loss='mse',
              optimizer=opt, metrics = ['mae'])
model.summary()
# Out:
# Model: "model_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_36 (InputLayer)       [(None, 999, 1)]          0
#
#  lstm_102 (LSTM)             (None, 999, 128)          66560
#
#  dense_21 (Dense)            (None, 999, 128)          16512
#
#  dense_22 (Dense)            (None, 999, 1)            129
#
# =================================================================
# Total params: 83,201
# Trainable params: 83,201
# Non-trainable params: 0
# _________________________________________________________________
# c:\Users\rando\anaconda3\envs\naparienv\lib\site-packages\keras\optimizers\optimizer_v2\rmsprop.py:135: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %% [markdown]
# Now let us plot the network graph using keras plot_model

# %%
from keras.utils import plot_model

model_inline = plot_model(model, to_file = './model_time_series.png', 
show_shapes = True, show_layer_names=True)

print(model_inline)
model_inline
# Out:
# <IPython.core.display.Image object>

# %% [markdown]
# Now let us start the model training by first defining some parameters like epochs, validation_split, keras callbacks etc

# %%
history = model.fit(stimuli_data_array, response_data_array,
              batch_size=batch_size,
              epochs=epochs,
              verbose = True,
              validation_split= validation_split,
              shuffle=True)
# Out:
# Epoch 1/150
# 1/1 [==============================] - 2s 2s/step - loss: 0.3271 - mae: 0.4605 - val_loss: 742.4874 - val_mae: 27.1542
# Epoch 2/150
# 1/1 [==============================] - 0s 173ms/step - loss: 735.8862 - mae: 26.9505 - val_loss: 159.9207 - val_mae: 10.5758
# Epoch 3/150
# 1/1 [==============================] - 0s 94ms/step - loss: 160.5954 - mae: 10.5960 - val_loss: 93.7752 - val_mae: 9.6564
# Epoch 4/150
# 1/1 [==============================] - 0s 97ms/step - loss: 94.2155 - mae: 9.6706 - val_loss: 27.0110 - val_mae: 5.1693
# Epoch 5/150
# 1/1 [==============================] - 0s 106ms/step - loss: 17.8864 - mae: 3.5998 - val_loss: 3.8662 - val_mae: 1.9268
# Epoch 6/150
# 1/1 [==============================] - 0s 117ms/step - loss: 1.3494 - mae: 0.8324 - val_loss: 1.7570 - val_mae: 1.2725
# Epoch 7/150
# 1/1 [==============================] - 0s 98ms/step - loss: 0.6549 - mae: 0.6174 - val_loss: 0.6430 - val_mae: 0.7182
# Epoch 8/150
# 1/1 [==============================] - 0s 111ms/step - loss: 0.2890 - mae: 0.4339 - val_loss: 0.2012 - val_mae: 0.3766
# Epoch 9/150
# 1/1 [==============================] - 0s 121ms/step - loss: 0.1435 - mae: 0.3194 - val_loss: 0.1492 - val_mae: 0.3190
# Epoch 10/150
# 1/1 [==============================] - 0s 98ms/step - loss: 0.1258 - mae: 0.3027 - val_loss: 0.2374 - val_mae: 0.4022
# Epoch 11/150
# 1/1 [==============================] - 0s 100ms/step - loss: 0.1442 - mae: 0.3188 - val_loss: 0.1275 - val_mae: 0.3199
# Epoch 12/150
# 1/1 [==============================] - 0s 117ms/step - loss: 0.1094 - mae: 0.2937 - val_loss: 0.1211 - val_mae: 0.3113
# Epoch 13/150
# 1/1 [==============================] - 0s 97ms/step - loss: 0.1064 - mae: 0.2906 - val_loss: 0.1209 - val_mae: 0.3112
# Epoch 14/150
# 1/1 [==============================] - 0s 102ms/step - loss: 0.1052 - mae: 0.2893 - val_loss: 0.1201 - val_mae: 0.3101
# Epoch 15/150
# 1/1 [==============================] - 0s 111ms/step - loss: 0.1045 - mae: 0.2883 - val_loss: 0.1196 - val_mae: 0.3094
# Epoch 16/150
# 1/1 [==============================] - 0s 97ms/step - loss: 0.1039 - mae: 0.2876 - val_loss: 0.1190 - val_mae: 0.3085
# Epoch 17/150
# 1/1 [==============================] - 0s 85ms/step - loss: 0.1035 - mae: 0.2869 - val_loss: 0.1184 - val_mae: 0.3077
# Epoch 18/150
# 1/1 [==============================] - 0s 91ms/step - loss: 0.1030 - mae: 0.2862 - val_loss: 0.1177 - val_mae: 0.3067
# Epoch 19/150
# 1/1 [==============================] - 0s 148ms/step - loss: 0.1026 - mae: 0.2855 - val_loss: 0.1170 - val_mae: 0.3059
# Epoch 20/150
# 1/1 [==============================] - 0s 88ms/step - loss: 0.1021 - mae: 0.2848 - val_loss: 0.1162 - val_mae: 0.3046
# Epoch 21/150
# 1/1 [==============================] - 0s 88ms/step - loss: 0.1016 - mae: 0.2840 - val_loss: 0.1156 - val_mae: 0.3041
# Epoch 22/150
# 1/1 [==============================] - 0s 91ms/step - loss: 0.1011 - mae: 0.2833 - val_loss: 0.1146 - val_mae: 0.3017
# Epoch 23/150
# 1/1 [==============================] - 0s 136ms/step - loss: 0.1006 - mae: 0.2823 - val_loss: 0.1170 - val_mae: 0.3066
# Epoch 24/150
# 1/1 [==============================] - 0s 89ms/step - loss: 0.1007 - mae: 0.2826 - val_loss: 0.1387 - val_mae: 0.3078
# Epoch 25/150
# 1/1 [==============================] - 0s 114ms/step - loss: 0.1089 - mae: 0.2850 - val_loss: 0.3050 - val_mae: 0.4511
# Epoch 26/150
# 1/1 [==============================] - 0s 89ms/step - loss: 0.1614 - mae: 0.3275 - val_loss: 0.1535 - val_mae: 0.3243
# Epoch 27/150
# 1/1 [==============================] - 0s 92ms/step - loss: 0.1149 - mae: 0.2916 - val_loss: 0.1444 - val_mae: 0.3332
# Epoch 28/150
# 1/1 [==============================] - 0s 139ms/step - loss: 0.1082 - mae: 0.2885 - val_loss: 0.1257 - val_mae: 0.3096
# Epoch 29/150
# 1/1 [==============================] - 0s 103ms/step - loss: 0.1034 - mae: 0.2836 - val_loss: 0.1261 - val_mae: 0.3175
# Epoch 30/150
# 1/1 [==============================] - 0s 118ms/step - loss: 0.1019 - mae: 0.2831 - val_loss: 0.1208 - val_mae: 0.3069
# Epoch 31/150
# 1/1 [==============================] - 0s 149ms/step - loss: 0.1008 - mae: 0.2811 - val_loss: 0.1231 - val_mae: 0.3142
# Epoch 32/150
# 1/1 [==============================] - 0s 90ms/step - loss: 0.1003 - mae: 0.2810 - val_loss: 0.1203 - val_mae: 0.3051
# Epoch 33/150
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0999 - mae: 0.2794 - val_loss: 0.1263 - val_mae: 0.3169
# Epoch 34/150
# 1/1 [==============================] - 0s 119ms/step - loss: 0.1004 - mae: 0.2802 - val_loss: 0.1279 - val_mae: 0.3060
# Epoch 35/150
# 1/1 [==============================] - 0s 98ms/step - loss: 0.1022 - mae: 0.2791 - val_loss: 0.1572 - val_mae: 0.3417
# Epoch 36/150
# 1/1 [==============================] - 0s 93ms/step - loss: 0.1096 - mae: 0.2860 - val_loss: 0.1890 - val_mae: 0.3425
# Epoch 37/150
# 1/1 [==============================] - 0s 131ms/step - loss: 0.1238 - mae: 0.2924 - val_loss: 0.3227 - val_mae: 0.4665
# Epoch 38/150
# 1/1 [==============================] - 0s 102ms/step - loss: 0.1653 - mae: 0.3283 - val_loss: 0.3375 - val_mae: 0.4734
# Epoch 39/150
# 1/1 [==============================] - 0s 97ms/step - loss: 0.1800 - mae: 0.3404 - val_loss: 0.4251 - val_mae: 0.5571
# Epoch 40/150
# 1/1 [==============================] - 0s 87ms/step - loss: 0.2019 - mae: 0.3617 - val_loss: 0.0988 - val_mae: 0.2626
# Epoch 41/150
# 1/1 [==============================] - 0s 99ms/step - loss: 0.1877 - mae: 0.3464 - val_loss: 0.3594 - val_mae: 0.4969
# Epoch 42/150
# 1/1 [==============================] - 0s 104ms/step - loss: 0.1790 - mae: 0.3399 - val_loss: 0.0943 - val_mae: 0.2578
# Epoch 43/150
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0976 - mae: 0.2656 - val_loss: 0.2545 - val_mae: 0.3947
# Epoch 44/150
# 1/1 [==============================] - 0s 97ms/step - loss: 0.1511 - mae: 0.3132 - val_loss: 0.0816 - val_mae: 0.2510
# Epoch 45/150
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0814 - mae: 0.2506 - val_loss: 0.0799 - val_mae: 0.2490
# Epoch 46/150
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0796 - mae: 0.2481 - val_loss: 0.0788 - val_mae: 0.2468
# Epoch 47/150
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0785 - mae: 0.2461 - val_loss: 0.0777 - val_mae: 0.2449
# Epoch 48/150
# 1/1 [==============================] - 0s 159ms/step - loss: 0.0775 - mae: 0.2440 - val_loss: 0.0764 - val_mae: 0.2423
# Epoch 49/150
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0764 - mae: 0.2418 - val_loss: 0.0755 - val_mae: 0.2407
# Epoch 50/150
# 1/1 [==============================] - 0s 172ms/step - loss: 0.0752 - mae: 0.2396 - val_loss: 0.0740 - val_mae: 0.2370
# Epoch 51/150
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0742 - mae: 0.2374 - val_loss: 0.0744 - val_mae: 0.2385
# Epoch 52/150
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0737 - mae: 0.2361 - val_loss: 0.0750 - val_mae: 0.2317
# Epoch 53/150
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0767 - mae: 0.2366 - val_loss: 0.1061 - val_mae: 0.2815
# Epoch 54/150
# 1/1 [==============================] - 0s 93ms/step - loss: 0.1031 - mae: 0.2740 - val_loss: 0.2088 - val_mae: 0.3632
# Epoch 55/150
# 1/1 [==============================] - 0s 89ms/step - loss: 0.2229 - mae: 0.3818 - val_loss: 0.1331 - val_mae: 0.3132
# Epoch 56/150
# 1/1 [==============================] - 0s 93ms/step - loss: 0.1292 - mae: 0.3040 - val_loss: 0.1066 - val_mae: 0.2592
# Epoch 57/150
# 1/1 [==============================] - 0s 87ms/step - loss: 0.1077 - mae: 0.2645 - val_loss: 0.0771 - val_mae: 0.2448
# Epoch 58/150
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0751 - mae: 0.2395 - val_loss: 0.0704 - val_mae: 0.2266
# Epoch 59/150
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0725 - mae: 0.2316 - val_loss: 0.0672 - val_mae: 0.2289
# Epoch 60/150
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0668 - mae: 0.2268 - val_loss: 0.0643 - val_mae: 0.2214
# Epoch 61/150
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0650 - mae: 0.2226 - val_loss: 0.0634 - val_mae: 0.2211
# Epoch 62/150
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0635 - mae: 0.2202 - val_loss: 0.0615 - val_mae: 0.2164
# Epoch 63/150
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0621 - mae: 0.2171 - val_loss: 0.0605 - val_mae: 0.2151
# Epoch 64/150
# 1/1 [==============================] - 0s 143ms/step - loss: 0.0606 - mae: 0.2146 - val_loss: 0.0587 - val_mae: 0.2105
# Epoch 65/150
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0592 - mae: 0.2112 - val_loss: 0.0576 - val_mae: 0.2094
# Epoch 66/150
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0578 - mae: 0.2089 - val_loss: 0.0557 - val_mae: 0.2037
# Epoch 67/150
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0563 - mae: 0.2049 - val_loss: 0.0550 - val_mae: 0.2047
# Epoch 68/150
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0550 - mae: 0.2040 - val_loss: 0.0534 - val_mae: 0.1961
# Epoch 69/150
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0543 - mae: 0.1988 - val_loss: 0.0561 - val_mae: 0.2084
# Epoch 70/150
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0558 - mae: 0.2063 - val_loss: 0.0651 - val_mae: 0.1973
# Epoch 71/150
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0680 - mae: 0.2064 - val_loss: 0.1007 - val_mae: 0.2768
# Epoch 72/150
# 1/1 [==============================] - 0s 88ms/step - loss: 0.1004 - mae: 0.2734 - val_loss: 0.1583 - val_mae: 0.3215
# Epoch 73/150
# 1/1 [==============================] - 0s 109ms/step - loss: 0.1687 - mae: 0.3367 - val_loss: 0.0805 - val_mae: 0.2484
# Epoch 74/150
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0789 - mae: 0.2420 - val_loss: 0.0642 - val_mae: 0.1958
# Epoch 75/150
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0677 - mae: 0.2055 - val_loss: 0.0477 - val_mae: 0.1950
# Epoch 76/150
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0473 - mae: 0.1924 - val_loss: 0.0431 - val_mae: 0.1784
# Epoch 77/150
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0439 - mae: 0.1803 - val_loss: 0.0413 - val_mae: 0.1799
# Epoch 78/150
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0413 - mae: 0.1789 - val_loss: 0.0386 - val_mae: 0.1700
# Epoch 79/150
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0391 - mae: 0.1708 - val_loss: 0.0368 - val_mae: 0.1692
# Epoch 80/150
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0370 - mae: 0.1686 - val_loss: 0.0344 - val_mae: 0.1597
# Epoch 81/150
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0348 - mae: 0.1606 - val_loss: 0.0326 - val_mae: 0.1591
# Epoch 82/150
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0327 - mae: 0.1586 - val_loss: 0.0302 - val_mae: 0.1471
# Epoch 83/150
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0307 - mae: 0.1487 - val_loss: 0.0291 - val_mae: 0.1519
# Epoch 84/150
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0291 - mae: 0.1508 - val_loss: 0.0290 - val_mae: 0.1330
# Epoch 85/150
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0300 - mae: 0.1375 - val_loss: 0.0403 - val_mae: 0.1781
# Epoch 86/150
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0402 - mae: 0.1765 - val_loss: 0.0787 - val_mae: 0.2310
# Epoch 87/150
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0838 - mae: 0.2417 - val_loss: 0.1044 - val_mae: 0.2927
# Epoch 88/150
# 1/1 [==============================] - 0s 119ms/step - loss: 0.1049 - mae: 0.2932 - val_loss: 0.1311 - val_mae: 0.3192
# Epoch 89/150
# 1/1 [==============================] - 0s 83ms/step - loss: 0.1394 - mae: 0.3317 - val_loss: 0.0855 - val_mae: 0.2646
# Epoch 90/150
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0862 - mae: 0.2657 - val_loss: 0.1494 - val_mae: 0.3212
# Epoch 91/150
# 1/1 [==============================] - 0s 116ms/step - loss: 0.1361 - mae: 0.3041 - val_loss: 0.4001 - val_mae: 0.6001
# Epoch 92/150
# 1/1 [==============================] - 0s 84ms/step - loss: 0.4267 - mae: 0.6229 - val_loss: 0.6461 - val_mae: 0.7897
# Epoch 93/150
# 1/1 [==============================] - 0s 90ms/step - loss: 0.6623 - mae: 0.7995 - val_loss: 0.4175 - val_mae: 0.5957
# Epoch 94/150
# 1/1 [==============================] - 0s 89ms/step - loss: 0.4378 - mae: 0.6165 - val_loss: 0.0448 - val_mae: 0.1859
# Epoch 95/150
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0424 - mae: 0.1788 - val_loss: 0.0331 - val_mae: 0.1518
# Epoch 96/150
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0346 - mae: 0.1565 - val_loss: 0.0280 - val_mae: 0.1516
# Epoch 97/150
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0273 - mae: 0.1489 - val_loss: 0.0253 - val_mae: 0.1428
# Epoch 98/150
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0251 - mae: 0.1420 - val_loss: 0.0236 - val_mae: 0.1387
# Epoch 99/150
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0232 - mae: 0.1371 - val_loss: 0.0215 - val_mae: 0.1320
# Epoch 100/150
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0213 - mae: 0.1309 - val_loss: 0.0197 - val_mae: 0.1265
# Epoch 101/150
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0194 - mae: 0.1251 - val_loss: 0.0177 - val_mae: 0.1197
# Epoch 102/150
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0175 - mae: 0.1186 - val_loss: 0.0160 - val_mae: 0.1136
# Epoch 103/150
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0157 - mae: 0.1123 - val_loss: 0.0141 - val_mae: 0.1063
# Epoch 104/150
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0139 - mae: 0.1053 - val_loss: 0.0125 - val_mae: 0.0998
# Epoch 105/150
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0122 - mae: 0.0986 - val_loss: 0.0108 - val_mae: 0.0919
# Epoch 106/150
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0106 - mae: 0.0912 - val_loss: 0.0094 - val_mae: 0.0859
# Epoch 107/150
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0091 - mae: 0.0848 - val_loss: 0.0080 - val_mae: 0.0764
# Epoch 108/150
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0079 - mae: 0.0763 - val_loss: 0.0075 - val_mae: 0.0756
# Epoch 109/150
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0071 - mae: 0.0740 - val_loss: 0.0084 - val_mae: 0.0674
# Epoch 110/150
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0088 - mae: 0.0711 - val_loss: 0.0277 - val_mae: 0.1553
# Epoch 111/150
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0273 - mae: 0.1542 - val_loss: 0.1029 - val_mae: 0.3035
# Epoch 112/150
# 1/1 [==============================] - 0s 112ms/step - loss: 0.1106 - mae: 0.3160 - val_loss: 0.0462 - val_mae: 0.2072
# Epoch 113/150
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0451 - mae: 0.2040 - val_loss: 0.0384 - val_mae: 0.1689
# Epoch 114/150
# 1/1 [==============================] - 0s 133ms/step - loss: 0.0424 - mae: 0.1805 - val_loss: 0.0123 - val_mae: 0.0951
# Epoch 115/150
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0113 - mae: 0.0895 - val_loss: 0.0064 - val_mae: 0.0629
# Epoch 116/150
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0070 - mae: 0.0670 - val_loss: 0.0050 - val_mae: 0.0574
# Epoch 117/150
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0045 - mae: 0.0543 - val_loss: 0.0036 - val_mae: 0.0471
# Epoch 118/150
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0036 - mae: 0.0487 - val_loss: 0.0033 - val_mae: 0.0453
# Epoch 119/150
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0030 - mae: 0.0434 - val_loss: 0.0027 - val_mae: 0.0402
# Epoch 120/150
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0027 - mae: 0.0414 - val_loss: 0.0027 - val_mae: 0.0402
# Epoch 121/150
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0024 - mae: 0.0384 - val_loss: 0.0023 - val_mae: 0.0366
# Epoch 122/150
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0023 - mae: 0.0382 - val_loss: 0.0027 - val_mae: 0.0407
# Epoch 123/150
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0024 - mae: 0.0385 - val_loss: 0.0029 - val_mae: 0.0408
# Epoch 124/150
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0031 - mae: 0.0437 - val_loss: 0.0053 - val_mae: 0.0642
# Epoch 125/150
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0050 - mae: 0.0621 - val_loss: 0.0115 - val_mae: 0.0961
# Epoch 126/150
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0125 - mae: 0.1015 - val_loss: 0.0288 - val_mae: 0.1658
# Epoch 127/150
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0290 - mae: 0.1667 - val_loss: 0.0726 - val_mae: 0.2567
# Epoch 128/150
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0781 - mae: 0.2673 - val_loss: 0.0390 - val_mae: 0.1947
# Epoch 129/150
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0386 - mae: 0.1939 - val_loss: 0.0414 - val_mae: 0.1863
# Epoch 130/150
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0454 - mae: 0.1968 - val_loss: 0.0168 - val_mae: 0.1266
# Epoch 131/150
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0162 - mae: 0.1240 - val_loss: 0.0205 - val_mae: 0.1270
# Epoch 132/150
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0228 - mae: 0.1358 - val_loss: 0.0079 - val_mae: 0.0828
# Epoch 133/150
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0073 - mae: 0.0790 - val_loss: 0.0057 - val_mae: 0.0647
# Epoch 134/150
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0065 - mae: 0.0701 - val_loss: 0.0047 - val_mae: 0.0618
# Epoch 135/150
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0043 - mae: 0.0584 - val_loss: 0.0038 - val_mae: 0.0518
# Epoch 136/150
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0043 - mae: 0.0562 - val_loss: 0.0040 - val_mae: 0.0572
# Epoch 137/150
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0037 - mae: 0.0545 - val_loss: 0.0043 - val_mae: 0.0567
# Epoch 138/150
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0049 - mae: 0.0612 - val_loss: 0.0060 - val_mae: 0.0729
# Epoch 139/150
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0058 - mae: 0.0714 - val_loss: 0.0097 - val_mae: 0.0882
# Epoch 140/150
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0107 - mae: 0.0940 - val_loss: 0.0143 - val_mae: 0.1157
# Epoch 141/150
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0143 - mae: 0.1157 - val_loss: 0.0278 - val_mae: 0.1540
# Epoch 142/150
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0303 - mae: 0.1620 - val_loss: 0.0225 - val_mae: 0.1459
# Epoch 143/150
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0224 - mae: 0.1459 - val_loss: 0.0339 - val_mae: 0.1668
# Epoch 144/150
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0371 - mae: 0.1764 - val_loss: 0.0133 - val_mae: 0.1117
# Epoch 145/150
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0130 - mae: 0.1102 - val_loss: 0.0158 - val_mae: 0.1112
# Epoch 146/150
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0177 - mae: 0.1190 - val_loss: 0.0111 - val_mae: 0.1016
# Epoch 147/150
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0108 - mae: 0.0998 - val_loss: 0.0175 - val_mae: 0.1188
# Epoch 148/150
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0194 - mae: 0.1265 - val_loss: 0.0205 - val_mae: 0.1386
# Epoch 149/150
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0204 - mae: 0.1385 - val_loss: 0.0503 - val_mae: 0.2059
# Epoch 150/150
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0553 - mae: 0.2177 - val_loss: 0.1113 - val_mae: 0.3319

# %%
def plot_history(history):
  plt.figure()
  plt.plot(history.epoch, np.array(history.history['mae']),
           label='Train Loss')
  plt.plot(history.epoch, np.array(history.history['val_mae']),
           label = 'Val loss')
  plt.legend()
  plt.ylim([0, 5])

plot_history(history)

# %%
prediction = model.predict(stimuli_data_array[0,:,:])[:,:,0]
print(prediction.shape)
time = np.arange(prediction.shape[0])
data = prediction.flatten()    
gt = stimuli_data_array[0,:,0]

plt.plot(time,data, color = 'r', linestyle='--')
plt.show()
plt.plot(time,gt, color = 'b', linestyle='dotted')
plt.show()
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 999, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 999, 1), dtype=tf.float32, name='input_36'), name='input_36', description="created by layer 'input_36'"), but it was called on an input with incompatible shape (None, 1, 1).
# 32/32 [==============================] - 0s 2ms/step
# (999, 1)
